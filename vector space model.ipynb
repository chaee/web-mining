# %% [markdown]
# ### TF-IDF
# - TF (tf_ij) = f_ij / max{f_1j, f_2j, ..., f_|v|j}
# - IDF (idf_i) = log(N/df_i) # N = total number of documents ; df_i = number of documents where t_i appears
# - TF-IDF(f_ij): weight of term t_i in document d_j; the number of times t_i appears in d_j
#
# ### Queries
#
# - w_iq = (0.5 + (0.5 * f_iq / max{f_1q, f_2q, ..., f_|V|q}) * log(N/df_i)
#
# ### Cosine similarity
# cosine (d_j, q) = <d_j @ q> / ||d_j|| * ||q||

# %%
import pandas as pd
import math
import numpy as np

# %%
word_freq_matrix = pd.read_csv('vsm.csv', index_col='Unnamed: 0')

# %%
word_freq_matrix
# Out:
#            antony and cleopatra  julius caesar  the tempest  hamlet  othello  \
# antony                      157             73            0       0        0
# brutus                        4            157            0       2        0
# caeser                      232            227            0       2        1
# calpurnia                     0             10            0       0        0
# cleopatra                    57              0            0       0        0
# mercy                         2              0            3       8        5
# worser                        2              0            1       1        1
#
#            macbeth
# antony           1
# brutus           0
# caeser           8
# calpurnia        0
# cleopatra        0
# mercy            5
# worser           0

# %%
# weight of 'Antony' in 'Antony and Cleopatra'
f_11 = word_freq_matrix['antony and cleopatra']['antony'] 
f_max = max(word_freq_matrix['antony and cleopatra'])
tf_11 = f_11 / f_max
print(f'tf_11 = {tf_11}')
# math.log(x, base)
idf_11 = math.log(6/word_freq_matrix.loc['antony'].astype(bool).sum(), 2)
print(f'idf_11 = {idf_11}')

w_11 = tf_11 * idf_11
print(f'w_11 = {w_11}')
# Out:
# tf_11 = 0.6767241379310345
# idf_11 = 1.0
# w_11 = 0.6767241379310345

# %%
weight_matrix = dict()

def calc_tfidf(term, doc):
    freq = word_freq_matrix[doc][term]
    freq_max = max(word_freq_matrix[doc])
    tf = freq / freq_max
    
    idf = math.log(6/word_freq_matrix.loc[term].astype(bool).sum(), 2)
    
    return format(tf*idf, '.3f')

for doc in word_freq_matrix.columns:
    weight_matrix[doc] = list()
    for query in word_freq_matrix.index:
        weight_matrix[doc].append(calc_tfidf(query, doc))

# %%
tfidf_weights = pd.DataFrame(data=weight_matrix, index=word_freq_matrix.index, dtype=float)
tfidf_weights
# Out:
#            antony and cleopatra  julius caesar  the tempest  hamlet  othello  \
# antony                    0.677          0.322        0.000   0.000    0.000
# brutus                    0.017          0.692        0.000   0.250    0.000
# caeser                    0.263          0.263        0.000   0.066    0.053
# calpurnia                 0.000          0.114        0.000   0.000    0.000
# cleopatra                 0.635          0.000        0.000   0.000    0.000
# mercy                     0.002          0.000        0.263   0.263    0.263
# worser                    0.005          0.000        0.195   0.073    0.117
#
#            macbeth
# antony       0.125
# brutus       0.000
# caeser       0.263
# calpurnia    0.000
# cleopatra    0.000
# mercy        0.164
# worser       0.000

# %%
# example of query 'Brutus Caeser'
def calc_query_weight(QUERY): 
    f_Vq = list()
    for term in list(word_freq_matrix.index):
        f_Vq.append(QUERY.count(term))    

    def calc_query_weight(term):
        f_iq = QUERY.count(term)
        idf = math.log(6/word_freq_matrix.loc[term].astype(bool).sum(), 2)
        weight = (0.5 + (0.5 * f_iq) / max(f_Vq)) * idf
        return format(weight ,'.2f')

    query_weight = list()
    for term in list(word_freq_matrix.index):
        query_weight.append(calc_query_weight(term))
    
    return pd.DataFrame(data=query_weight, dtype=float, index=word_freq_matrix.index)

query_weights = dict()
query_weights['brutus caeser'] = calc_query_weight('brutus caeser')

# %%
# calculate similarity scores between 
# the query 'Brutus Caeser'(q) and the document 'Antony and Cleopatra'(d_j)
query = 'brutus caeser'
#document = 'antony and cleopatra'

similarity_scores = list()
for document in word_freq_matrix.columns:
    w_ij = tfidf_weights[document]
    # print(f'w_ij: {w_ij}')
    w_iq = query_weights[query] 
    # print(f'w_iq: {w_iq}')

    # cos_sim = w_iq.mul(w_ij, axis=0).sum() / math.sqrt((np.square(w_ij).sum()) * math.sqrt(np.square(w_iq).sum()))
    cos_sim = w_iq.mul(w_ij, axis=0).sum() / math.sqrt(np.square(w_ij).sum()) * math.sqrt(np.square(w_iq).sum())
    similarity_scores.append(cos_sim)
similarity_scores
# Out:
# [0    2.810572
#  dtype: float64,
#  0    2.85518
#  dtype: float64,
#  0    0.603829
#  dtype: float64,
#  0    1.868973
#  dtype: float64,
#  0    0.609646
#  dtype: float64,
#  0    0.99222
#  dtype: float64]

# %%
document = 'antony and cleopatra'

w_ij = tfidf_weights[document]
# print(f'w_ij: {w_ij}')
w_iq = query_weights[query] 
# print(f'w_iq: {w_iq}')

# cos_sim = w_iq.mul(w_ij, axis=0).sum() / math.sqrt((np.square(w_ij).sum()) * math.sqrt(np.square(w_iq).sum()))
mul_dj_q = w_iq.mul(w_ij, axis=0).sum()
mod_dj = math.sqrt(np.square(w_ij).sum())
mod_q = math.sqrt(np.square(w_iq).sum())

cos_sim = mul_dj_q / mod_dj * mod_q
print(cos_sim)
# Out:
# 0    2.810572
# dtype: float64

# %%
# calculate similarity scores based on cosine similarity

for doc in word_freq_matrix.columns:
    w_ij = pd.DataFrame(data=weights[doc], index=word_freq_matrix.index)
    w_iq = pd.DataFrame(data={doc: query_weight}, dtype=float, index=word_freq_matrix.index)
    cos_sim = w_iq.mul(w_ij) / (np.square(w_ij).sum() + np.square(w_iq).sum())
    print(cos_sim)
# Out:
#            antony and cleopatra
# antony                 0.059618
# brutus                 0.002994
# caeser                 0.012043
# calpurnia              0.000000
# cleopatra              0.144271
# mercy                  0.000046
# worser                 0.000255
#            julius caesar
# antony          0.029751
# brutus          0.127876
# caeser          0.012636
# calpurnia       0.027175
# cleopatra       0.000000
# mercy           0.000000
# worser          0.000000
#            the tempest
# antony        0.000000
# brutus        0.000000
# caeser        0.000000
# calpurnia     0.000000
# cleopatra     0.000000
# mercy         0.007044
# worser        0.011650
#              hamlet
# antony     0.000000
# brutus     0.051144
# caeser     0.003511
# calpurnia  0.000000
# cleopatra  0.000000
# mercy      0.006994
# worser     0.004331
#             othello
# antony     0.000000
# brutus     0.000000
# caeser     0.002852
# calpurnia  0.000000
# cleopatra  0.000000
# mercy      0.007075
# worser     0.007021
#             macbeth
# antony     0.012864
# brutus     0.000000
# caeser     0.014074
# calpurnia  0.000000
# cleopatra  0.000000
# mercy      0.004388
# worser     0.000000

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-157-a0f4fafac82c> in <module>
# ----> 1 cos_Sim
#
# NameError: name 'cos_Sim' is not defined
